# %%
# 例: chunk_size=50 行ずつファイルを分割して定形プロンプトXと一緒に書き出す
chunk_size = 25
prompt_x = """

## 1. エスペラント語根リストについて
以下に示すのは、エスペラントの「語根」リストです（語根ではないものは末尾に # が付記されています）。  
各行には左から順に、  
1. エスペラント語根(ES)  
2. 信頼できる日本語訳(J)  
3. 信頼できる中国語訳(C1)(抜け落ち多数あり)  
4. 信頼できない中国語訳 (C2)（google翻訳）  
5. 信頼できる英語訳(E)  
が「|」で区切られて示されています。

## 2. タスク概要
- 目的: 与えられたエスペラント語根全てに対して、リストの順に、簡体字中国語の漢字(基本的に1文字)を割り当てる。  
- ただし:
  - どうしても漢字1文字での割当が難しい場合は、2文字以上の熟語を作ってもよい。  
  - それでも難しい場合は、その語根への割当をあえて行わない（未対応のままにする）という選択肢も認める。

## 3. エスペラント語根への漢字割当時に考慮してほしい4つの条件
1. **漢字の種類(または偏旁)の総数をできるだけ抑える**  
   - 漢字の重複割当は大歓迎。できる限り同じ漢字・偏旁を使い回す。


2. **日本人・中国人双方が“意味を連想しやすい”簡体字であること**  
   - 簡体字を用いるが、日本語圏の人にとっても意味がつかみやすい漢字・熟語を優先して選んでほしい。

3. **できるだけ画数が少ない漢字を優先する**  
   - 非漢字圏の学習者の負担を減らすために、筆画の多い漢字より画数の少ない漢字を優先して割り当てたい。

4. **1文字割当が困難なら、既出(または今後の割当予定)の偏旁や漢字を組み合わせた熟語を検討し、それでも難しければ割当を行わない**  
   - まず1文字で割当できないかを検討し、それが困難な場合は既に他のエスペラント語根に対して割り当てている(もしくは別の回も含む他の箇所で割り当てることになるであろう、汎用性の高い)偏旁や漢字を組み合わせた熟語を検討する。  
   - それでもなお難しければ、当該エスペラント語根への漢字割当は“未対応のまま”で構わない。

## 4. 作業の進め方・注意点
- 慎重かつ丁寧に、一切ミスがないよう検討してほしい。  
- リストの順に、エスペラント語根への割当を進めてほしい。


## 5. 各エスペラント語根への対応漢字を提案する際の推奨フォーマット  
**各エスペラント語根につき、以下の4項目(3と4は可能な範囲で)をスラッシュ「/」区切りで提示しください(スプレッドシート上での列分割を容易にするため)。1行につき1語根の対応を示す形式です。**

1. **エスペラント語根**  
2. **提案する簡体字(または熟語)**  
3. **(可能であれば)その字・熟語を選んだ理由や根拠**  
4. **(可能であれば)既出の偏旁や漢字との関係、学習コストに関する考察**  
   - すでに割り当て済みの偏旁や漢字を活用していれば、その点も記載  

### 5.1 出力例(イメージ)  
```
エスペラント語根1/提案漢字/選定理由/既出の偏旁や学習コストの考察
エスペラント語根2/提案熟語/選定理由/既出の偏旁や学習コストの考察
...
```

## 6. まとめ・最終要請
以上の指示に基づき、以下のエスペラント語根(各回約25件)全てに対する簡体字中国語の漢字・熟語の割当を、リストの順に、誤りがないよう慎重に丁寧に進めてください。  
学習コスト(偏旁総数)を極力抑えつつ、かつ日本語圏・中国語圏いずれの話者も概ね納得できる形での割当を、丁寧に提案・検討してください。  

どうぞよろしくお願いします。

# エスペラント語根リスト⇓

"""

input_file = "基于世界语词根的平均语义向量进行层次聚类排序后的,用于交由生成AI决定汉字分配的世界语词根及其日语,英语,汉语对应翻译列表.csv"  # あなたのCSVファイルのパスを指定
output_file_base = "output_chunk_"  # 出力ファイル名のベース

# CSVファイルをリストに読み込む
with open(input_file, "r", encoding="utf-8") as f:
    lines = f.readlines()

# 全行数を把握
total_lines = len(lines)

# 50行ずつ切り出してファイル書き出し
# iは0, 50, 100, 150, ... のように進み、最後は4736を超える手前で止まる
for i in range(0, total_lines, chunk_size):
    # [i:i+chunk_size] で該当の50行を抜き出し
    chunk = lines[i:i + chunk_size]
    # どのチャンクかを数えやすいようにインデックスを +1 しておく
    chunk_index = i // chunk_size + 1  # 1,2,3,... のように連番が入る

    # 出力先ファイル名: "output_chunk_1.txt" のようになる
    output_file = f"{output_file_base}{chunk_index}.txt"

    # テキストファイルに書き出し
    with open(output_file, "w", encoding="utf-8") as out_f:
        # まず定形プロンプトXを書き出す
        out_f.write(prompt_x)
        out_f.write("\n")  # 改行(必要に応じて)
        # 続いて50行分のCSVの中身を書き出す
        for line in chunk:
            # 末尾の改行が残っているはずなのでそのまま書き出してもOK
            # もしstripしたい場合は out_f.write(line.strip() + "\n") などとする
            out_f.write(line)

    print(f"{output_file} を出力しました。")

print("すべての分割ファイルの出力が完了しました。")
# Out:
# output_chunk_1.txt を出力しました。
# output_chunk_2.txt を出力しました。
# output_chunk_3.txt を出力しました。
# output_chunk_4.txt を出力しました。
# output_chunk_5.txt を出力しました。
# output_chunk_6.txt を出力しました。
# output_chunk_7.txt を出力しました。
# output_chunk_8.txt を出力しました。
# output_chunk_9.txt を出力しました。
# output_chunk_10.txt を出力しました。
# output_chunk_11.txt を出力しました。
# output_chunk_12.txt を出力しました。
# output_chunk_13.txt を出力しました。
# output_chunk_14.txt を出力しました。
# output_chunk_15.txt を出力しました。
# output_chunk_16.txt を出力しました。
# output_chunk_17.txt を出力しました。
# output_chunk_18.txt を出力しました。
# output_chunk_19.txt を出力しました。
# output_chunk_20.txt を出力しました。
# output_chunk_21.txt を出力しました。
# output_chunk_22.txt を出力しました。
# output_chunk_23.txt を出力しました。
# output_chunk_24.txt を出力しました。
# output_chunk_25.txt を出力しました。
# output_chunk_26.txt を出力しました。
# output_chunk_27.txt を出力しました。
# output_chunk_28.txt を出力しました。
# output_chunk_29.txt を出力しました。
# output_chunk_30.txt を出力しました。
# output_chunk_31.txt を出力しました。
# output_chunk_32.txt を出力しました。
# output_chunk_33.txt を出力しました。
# output_chunk_34.txt を出力しました。
# output_chunk_35.txt を出力しました。
# output_chunk_36.txt を出力しました。
# output_chunk_37.txt を出力しました。
# output_chunk_38.txt を出力しました。
# output_chunk_39.txt を出力しました。
# output_chunk_40.txt を出力しました。
# output_chunk_41.txt を出力しました。
# output_chunk_42.txt を出力しました。
# output_chunk_43.txt を出力しました。
# output_chunk_44.txt を出力しました。
# output_chunk_45.txt を出力しました。
# output_chunk_46.txt を出力しました。
# output_chunk_47.txt を出力しました。
# output_chunk_48.txt を出力しました。
# output_chunk_49.txt を出力しました。
# output_chunk_50.txt を出力しました。
# output_chunk_51.txt を出力しました。
# output_chunk_52.txt を出力しました。
# output_chunk_53.txt を出力しました。
# output_chunk_54.txt を出力しました。
# output_chunk_55.txt を出力しました。
# output_chunk_56.txt を出力しました。
# output_chunk_57.txt を出力しました。
# output_chunk_58.txt を出力しました。
# output_chunk_59.txt を出力しました。
# output_chunk_60.txt を出力しました。
# output_chunk_61.txt を出力しました。
# output_chunk_62.txt を出力しました。
# output_chunk_63.txt を出力しました。
# output_chunk_64.txt を出力しました。
# output_chunk_65.txt を出力しました。
# output_chunk_66.txt を出力しました。
# output_chunk_67.txt を出力しました。
# output_chunk_68.txt を出力しました。
# output_chunk_69.txt を出力しました。
# output_chunk_70.txt を出力しました。
# output_chunk_71.txt を出力しました。
# output_chunk_72.txt を出力しました。
# output_chunk_73.txt を出力しました。
# output_chunk_74.txt を出力しました。
# output_chunk_75.txt を出力しました。
# output_chunk_76.txt を出力しました。
# output_chunk_77.txt を出力しました。
# output_chunk_78.txt を出力しました。
# output_chunk_79.txt を出力しました。
# output_chunk_80.txt を出力しました。
# output_chunk_81.txt を出力しました。
# output_chunk_82.txt を出力しました。
# output_chunk_83.txt を出力しました。
# output_chunk_84.txt を出力しました。
# output_chunk_85.txt を出力しました。
# output_chunk_86.txt を出力しました。
# output_chunk_87.txt を出力しました。
# output_chunk_88.txt を出力しました。
# output_chunk_89.txt を出力しました。
# output_chunk_90.txt を出力しました。
# output_chunk_91.txt を出力しました。
# output_chunk_92.txt を出力しました。
# output_chunk_93.txt を出力しました。
# output_chunk_94.txt を出力しました。
# output_chunk_95.txt を出力しました。
# output_chunk_96.txt を出力しました。
# output_chunk_97.txt を出力しました。
# output_chunk_98.txt を出力しました。
# output_chunk_99.txt を出力しました。
# output_chunk_100.txt を出力しました。
# output_chunk_101.txt を出力しました。
# output_chunk_102.txt を出力しました。
# output_chunk_103.txt を出力しました。
# output_chunk_104.txt を出力しました。
# output_chunk_105.txt を出力しました。
# output_chunk_106.txt を出力しました。
# output_chunk_107.txt を出力しました。
# output_chunk_108.txt を出力しました。
# output_chunk_109.txt を出力しました。
# output_chunk_110.txt を出力しました。
# output_chunk_111.txt を出力しました。
# output_chunk_112.txt を出力しました。
# output_chunk_113.txt を出力しました。
# output_chunk_114.txt を出力しました。
# output_chunk_115.txt を出力しました。
# output_chunk_116.txt を出力しました。
# output_chunk_117.txt を出力しました。
# output_chunk_118.txt を出力しました。
# output_chunk_119.txt を出力しました。
# output_chunk_120.txt を出力しました。
# output_chunk_121.txt を出力しました。
# output_chunk_122.txt を出力しました。
# output_chunk_123.txt を出力しました。
# output_chunk_124.txt を出力しました。
# output_chunk_125.txt を出力しました。
# output_chunk_126.txt を出力しました。
# output_chunk_127.txt を出力しました。
# output_chunk_128.txt を出力しました。
# output_chunk_129.txt を出力しました。
# output_chunk_130.txt を出力しました。
# output_chunk_131.txt を出力しました。
# output_chunk_132.txt を出力しました。
# output_chunk_133.txt を出力しました。
# output_chunk_134.txt を出力しました。
# output_chunk_135.txt を出力しました。
# output_chunk_136.txt を出力しました。
# output_chunk_137.txt を出力しました。
# output_chunk_138.txt を出力しました。
# output_chunk_139.txt を出力しました。
# output_chunk_140.txt を出力しました。
# output_chunk_141.txt を出力しました。
# output_chunk_142.txt を出力しました。
# output_chunk_143.txt を出力しました。
# output_chunk_144.txt を出力しました。
# output_chunk_145.txt を出力しました。
# output_chunk_146.txt を出力しました。
# output_chunk_147.txt を出力しました。
# output_chunk_148.txt を出力しました。
# output_chunk_149.txt を出力しました。
# output_chunk_150.txt を出力しました。
# output_chunk_151.txt を出力しました。
# output_chunk_152.txt を出力しました。
# output_chunk_153.txt を出力しました。
# output_chunk_154.txt を出力しました。
# output_chunk_155.txt を出力しました。
# output_chunk_156.txt を出力しました。
# output_chunk_157.txt を出力しました。
# output_chunk_158.txt を出力しました。
# output_chunk_159.txt を出力しました。
# output_chunk_160.txt を出力しました。
# output_chunk_161.txt を出力しました。
# output_chunk_162.txt を出力しました。
# output_chunk_163.txt を出力しました。
# output_chunk_164.txt を出力しました。
# output_chunk_165.txt を出力しました。
# output_chunk_166.txt を出力しました。
# output_chunk_167.txt を出力しました。
# output_chunk_168.txt を出力しました。
# output_chunk_169.txt を出力しました。
# output_chunk_170.txt を出力しました。
# output_chunk_171.txt を出力しました。
# output_chunk_172.txt を出力しました。
# output_chunk_173.txt を出力しました。
# output_chunk_174.txt を出力しました。
# output_chunk_175.txt を出力しました。
# output_chunk_176.txt を出力しました。
# output_chunk_177.txt を出力しました。
# output_chunk_178.txt を出力しました。
# output_chunk_179.txt を出力しました。
# output_chunk_180.txt を出力しました。
# output_chunk_181.txt を出力しました。
# output_chunk_182.txt を出力しました。
# output_chunk_183.txt を出力しました。
# output_chunk_184.txt を出力しました。
# output_chunk_185.txt を出力しました。
# output_chunk_186.txt を出力しました。
# output_chunk_187.txt を出力しました。
# output_chunk_188.txt を出力しました。
# output_chunk_189.txt を出力しました。
# output_chunk_190.txt を出力しました。
# すべての分割ファイルの出力が完了しました。
